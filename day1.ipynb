# %%
#Basic Syntax 
print("Hello world!!") #printing
# Out:
# Hello world!!

# %%
#Capitalize
text = "hello world" #string
print(text.capitalize()) #capitalizing the string
# Out:
# Hello world

# %%
#casefolding
text = "HELLO woRLD" #string
print(text.casefold()) #casefolding the string
# Out:
# hello world

# %%
#center
text = "hello world" #string
print(text.center(20, '-')) #centering the string
# Out:
# ----hello world-----

# %%
#count
print(text.count('o')) #counting the number of occurrences of 'o' in the string
# Out:
# 2

# %%
#encode
print(text.encode()) #encoding the string
# Out:
# b'hello world'

# %%
#endswith
print(text.endswith('world')) 
#checking if the string ends with 'world'
# Out:
# True

# %%
print(text.endswith('worl'))
# Out:
# False

# %%
#expandtabs
text = "hello\tworld" 
print(text.expandtabs(2)) #Replacing the tab character with 2 spaces
# Out:
# hello world

# %%
#find
print(text.find('world')) #finding the index of the first occurrence of 'world' in the string
# Out:
# 6

# %%
#format
print("Hello {}!".format("world")) #formatting the string

#formatting puts the values inside the culry braces in the string
# Out:
# Hello world!

# %%
#format_map

print("Hello {name}!".format_map({'name': 'world'})) #formatting the string using a dictionary
# Out:
# Hello world!

# %%
print("He got {n} marks in exam".format_map({'n':90}))
# Out:
# He got 90 marks in exam

# %%
#index
print(text.index('d'))
# Out:
# 10

# %%
#isalnum
print(text.isalnum()) #checking if the string is alphanumeric
# Out:
# False

# %%
text='helloworld1'
print(text.isalnum()) #checking if the string is alphanumeric
# Out:
# True

# %%
#isalpha
print(text.isalpha()) #checking if the string is alphabetic
# Out:
# False

# %%
print("ram".isalpha()) #checking if the string is alphabetic
# Out:
# True

# %%
#isascii
print(text.isascii()) #checking if the string is ascii
# Out:
# True

# %%
print("23@_é".isascii()) #checking if the string is ascii
# Out:
# False

# %%
#isdecimal
print("90".isdecimal()) #checking if the string is decimal
# Out:
# True

# %%
#isdigit
print("90".isdigit()) #checking if the string is digit
# Out:
# True

# %%
#isidentifier
print("hello_world".isidentifier()) #checking if the string is a valid identifier
# Out:
# True

# %%
#islower
print(text.lower())
# Out:
# helloworld1

# %%
#isnumeric
print("90".isnumeric()) #checking if the string is numeric
# Out:
# True

# %%
print(" ".isnumeric())
# Out:
# False

# %%
#isprintable
print(text.isprintable()) #checking if the string is printable
# Out:
# True

# %%
#isspace
text =" ar hi "
print(text.isspace()) #checking if the string is whitespace
# Out:
# False

# %%
text = " "
print(text.isspace()) #checking if the string is whitespace
# Out:
# True

# %%
#isupper
print(text.isupper()) #checking if the string is uppercase
# Out:
# False

# %%
#title
text = "hello world" #string
print(text.title()) #converting the string to title case
# Out:
# Hello World

# %%
#join
t1 ="Ram, "
t2 ="Shyam, "
t3 ="Hari"
print(t1.join([t2, t3])) #joining the strings using the join()
# Out:
# Shyam, Ram, Hari

# %%
#ljust
text = "hello"
print(text.ljust(20, '-')) #left justifying the string with '-' padding
# Out:
# hello---------------

# %%
#lower
print(text.lower()) #converting the string to lowercase
# Out:
# hello

# %%
#lstrip
print(text.lstrip('h')) #removing the leading 'h' from the string
# Out:
# ello

# %%
#partition
print(text.partition('l')) #partitioning the string at the first occurrence of 'l'
# Out:
# ('he', 'l', 'lo')

# %%
#maketrans
print(text.maketrans('h', 'H')) #creating a translation table for replacing 'h' with 'H'
# Out:
# {104: 72}

# %%
#removeprefix
print(text.removeprefix('he')) #removing the prefix 'he' from the string
# Out:
# llo

# %%
#removesuffix
print(text.removesuffix('lo')) #removing the suffix 'lo' from the string
# Out:
# hel

# %%
#replace
print(text.replace('l', 'L')) #replacing all occurrences of 'l' with 'L' in the string
# Out:
# heLLo

# %%
#rfind
print(text.rfind('l')) #finding the index of the last occurrence of 'l' in the string
# Out:
# 3

# %%
print(text.rfind('o'))
# Out:
# 4

# %%
#rjust
print(text.rjust(20, '-')) #right justifying the string with '-' padding
# Out:
# ---------------hello

# %%
#rpartition
print(text.rpartition('l')) #partitioning the string at the last occurrence of 'l'
# Out:
# ('hel', 'l', 'o')

# %%
#rsplit
print(text.rsplit('l')) #splitting the string at the last occurrence of 'l'
# Out:
# ['he', '', 'o']

# %%
#rstrip
print(text.rstrip('o')) #removing the trailing 'o' from the string
# Out:
# hell

# %%
#split
print(text.split('l')) #splitting the string at each occurrence of 'l'
# Out:
# ['he', '', 'o']

# %%
#splitlines
print(text.splitlines()) #splitting the string at each line break
# Out:
# ['hello']

# %%
#startswith
print(text.startswith('he')) #checking if the string starts with 'he'
# Out:
# True

# %%
#strip
text="helloh"
print(text.strip('h')) #removing the leading and trailing 'h' from the string
# Out:
# ello

# %%
#swapcase
print(text.swapcase()) #swapping the case of the string
# Out:
# HELLOH

# %%
#title
print(text.title()) #converting the string to title case
# Out:
# Helloh

# %%
#translate
print(text.translate(text.maketrans('h', 'H'))) #translating the string using the translation table
# Out:
# HelloH

# %%
#upper
print(text.upper()) #converting the string to uppercase
# Out:
# HELLOH

# %%
#zfill
print(text.zfill(30)) #padding the string with zeros on the left to make it 20 characters long
# Out:
# 000000000000000000000000helloh
