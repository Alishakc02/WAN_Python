# %% [markdown]
# OPERATORS
# 3) COMPARISON OPERATORS
#    A) == equal
#    B) !=
#    C) >
#    D) <
#    E) >=
#    F) <= returns(True or False)
#
# 4) Assignment operators
#    (=,(+, -, *, /, //, **, %)=,(|, &, ^, <<, >>)=)
#
# 5) Logical / Rational operators
#     (and, or, not) returns (True | False)
#
# 6) Identity (is, not is) (True | False)
# 7) Membership (in, not in) (True | False)

# %%
x=2
y=5
print(x|y)
# Out:
# 7

# %%
print(5<<2)
# Out:
# 20

# %%
#Membership operator
x=[1,2]
y=[1,2]
z=x
print(x is y)
print(x is z)
print(z is y)
# Out:
# False
# True
# False

# %%
#Memory address
print(id(x))
print(id(y))
print(id(z))
# Out:
# 4854062144
# 4854030528
# 4854062144

# %% [markdown]
# Membership Operator
# a) in, not in

# %%
a={1,2,3,4}
print(1 in a)
# Out:
# True

# %%
print(1 not in a)
# Out:
# False

# %% [markdown]
# OPERATOR PRECEDENCE

# %%
x=(14+6)%7*3//2+1
print(x)
# Out:
# 10

# %%
x=12 | 14 & 8 ^ 12
print(x)
# Out:
# 12

# %%
x=(12*3)//3**2+12^14<<2>>1&121//6**2
print(x)
# Out:
# 16

# %%
x= 15 // 2 ** 2 % 3 + 12 ^ 45 >> 2 & 19 | 8 < 5
print(x)
# Out:
# False

# %%
x=(28 & 15) << 2 + 1 ^ 84 // 4 % 3 
print(x)
# Out:
# 96

# %%
print(28 & 15)
# Out:
# 12

# %%
print(84//4)
# Out:
# 21

# %%
print(21%3)
# Out:
# 0

# %%
print(96^0)
# Out:
# 96

# %%
x=100 >> 2 == 25 & 14 | 3
print(x)
# Out:
# False

# %%
print(~15)
# Out:
# -16

# %%
x= (~15) + (18 ^ 24) >> 2 & 7
print(x)
# Out:
# 6

# %%
print(-16+10)
# Out:
# -6

# %%
print(-6>>2)
# Out:
# -2

# %%
x=5 * 4 // 3 % 2 ** 2 + 14 << 1 ^ 19 & 11
print(x)
# Out:
# 35

# %%
x= 56 // 3 % 4 * 2 ** 3 + 18 ^ 25 >> 2 & 144 // 12 | 7 < 12
print(x)
# Out:
# False
