# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishakc02/WAN_Python/blob/main/conditional_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Positive, Negative, and Zero (if-elif-else)

# %%
a = int(input("Enter a number:"))
if a > 0:
  print(f"{a} is Positive number")
elif a < 0:
  print(f"{a} is Negative number")
else:
  print(f"{a} is Zero")
# Out:
# Enter a number:-1
# -1 is Negative number

# %% [markdown]
# 2. Even - Odd

# %%
b = int(input("Enter a number: "))
if(b%2 == 0):
  print(f"{b} is Even number")
else:
  print(f"{b} is Odd number")
# Out:
# Enter a number: 1
# 1 is Odd number

# %% [markdown]
# 3) Voting Eligibility

# %%
age = int(input("Enter your age: "))
if(age >= 18):
  print("You are eligible for voting")
else:
  print("You are not eligible for voting")
# Out:
# Enter your age: 12
# You are not eligible for voting

# %% [markdown]
# 4) Grade Calculator

# %%
marks = int(input("Enter your marks: "))
if(marks >=90 and marks <=100):
  print("Grade A")
elif(marks >=80 and marks <90):
  print("Grade B")
elif(marks >=70 and marks <80):
  print("Grade C")
elif(marks >=60 and marks <70):
  print("Grade D")
else:
  print("Grade F")
# Out:
# Enter your marks: 98
# Grade A

# %% [markdown]
# 5) Largest of three numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if(a>b and a>c):
  print(f"{a} is the largest number")
elif(b>a and b>c):
  print(f"{b} is the largest number")
else:
  print(f"{c} is the largest number")1
# Out:
# Enter first number: 78
# Enter second number: 3
# Enter third number: 23
# 78 is the largest number
